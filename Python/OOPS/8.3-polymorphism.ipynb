# %% [markdown]
# ## Method Overriding
# Method overriding allows a child class to provinde specific implimentation of a method that is already defined in its parent class

# %%
## Base class
class Animal:
    def speak(self):
        return "Sound of the Animal"
# Derived Class 
class Dog(Animal):
    def speak(self):
        return "wooof!"
class Cat(Animal):
    def speak(self):
        return "meow!"
def animal_speak(animal):
    print(animal.speak())

# %%
dog= Dog()
print(dog.speak())
cat = Cat()
print(cat.speak())
animal=Animal()
print(animal.speak())
print("-----------")
animal_speak(dog)
animal_speak(cat)
# Out:
# wooof!
# meow!
# Sound of the Animal
# -----------
# wooof!
# meow!

# %% [markdown]
# ## Ploymirphisum with functions and methods

# %%
# base class 
class Shape:
    def area(self):
        print("The area of figure")
##Derived class 
class Rectalge(Shape):
    def __init__(self, width,height):
        self.width= width
        self.height= height
    def area(self):
        return self.width * self.height
#Derived class 2

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return  3.14 * (self.radius * self.radius)
    
# Function thatr demonstrate the Polymorphisum

shapeR= Rectalge(2,4)
shapeC= Circle(4)


def print_area(shape):
    print(shape.area())


print_area(shapeC)
print_area(shapeR)
# Out:
# 50.24
# 8

# %% [markdown]
# ## POLYMORPHISUM WITH ABSTRACT BASE CLASS (INTERFACES)
# we must need to implement the abstact method otherwise we will get error

# %%
from abc import ABC, abstractmethod
# Define abstract class
class Vehicle(ABC):
    @abstractmethod
    def startEngine(self):
        pass

##Drivided Class
class Car(Vehicle):
    pass
    def startEngine(self):
        return "Car Engine Started"
# Derived class 
class Bike(Vehicle):
    def startEngine(self):
        return "Bike Engine started"
def start_vehicle(vehicle):
    print(vehicle.startEngine())


#create the objects 
car= Car()
bike= Bike()
start_vehicle(car)
start_vehicle(bike)
# Out:
# Car Engine Started
# Bike Engine started
