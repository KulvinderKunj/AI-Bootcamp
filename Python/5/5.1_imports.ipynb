# %%
import math
import numpy as nb
import pandas as pd


math.sqrt(16)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import math
#       2 import numpy as nb
# ----> 3 import pandas as pd
#       6 math.sqrt(16)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
from math import sqrt,pi
print(sqrt(25))
print(sqrt(16))
print(pi)
# Out:
# 5.0
# 4.0
# 3.141592653589793

# %%
import numpy as np


import sys
print(sys.executable)
# Out:
# c:\Users\kalvi\anaconda3\python.exe
