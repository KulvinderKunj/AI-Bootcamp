# %%
# Read the whole file  
with open("example.txt", "r" ) as file:
    content = file.read()
    print(content)
    # for lins in file:
# Out:
# Hello this is kulvinder singh
# I am doing MS Artificial Intelligence

# %%
# Read Line By line  
with open("example.txt", "r") as file:
    for line in file:
        print(line.strip()) # to remove new line space
# Out:
# Hello this is kulvinder singh
# I am doing MS Artificial Intelligence

# %%
# Writing in file  (with overWriting)
with open("example.txt", "w")as file:
    file.write("Hello World! \n")
    file.write("Hello Kulvinder Singh \n")

# %%
# Writing in file  (withouth overWriting)
with open("example.txt", "a")as file:
    file.write("This line is Appended \n")

# %%
# Writing a list of lines to file 
lines = ["first line \n", "second linen\n","Third Line \n"]

with open("example.txt","a") as file:
    file.writelines(lines)

# %%
# Binary Files
data = b"\x00\x01\x03\x04"
with open("example.txt","wb") as file :
    
    file.write(data)

# %%
# read the binary file
with open("example.txt", "rb") as file:
    content=file.read()
    print(content)
# Out:
# b'\x00\x01\x03\x04'

# %%
# Binary Files
with open("example.txt","r") as source_file :
    content=source_file.read()




with open("destination.txt","w") as destinaiton:
    
    destinaiton.write(content)

# %%
# Count the Number of LIne 
def count_text_file(filePath):
    with open (filePath, "r") as file:
      lines = file.readlines()
      line_count= len(lines)
      word_count = sum(len(line.split()) for line in lines)
      char_count = sum(len(line) for line in lines)
    return line_count, word_count, char_count

filePath = "example.txt"
lines, words, charachers= count_text_file(filePath)
print(f"Lines: {lines} Words : {words}  Characters : {charachers}")
# Out:
# Lines: 2 Words : 7  Characters : 34

# %%
# Writing  and Reading File
with open("example.txt", "w+")as file:
    file.write("Hello World \n")
    file.write("this is new Line \n")

    # Move the file cursor to the begining 
    file.seek(0)
    # Can red the content of file 
    content= file.read()


    print(content)
# Out:
# Hello World
# this is new Line
