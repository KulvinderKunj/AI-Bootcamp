# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello World !")
# Out:
# Hello World !

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
value = input("Enter Value:")
print("Entered Value is ",value)
# Out:
# Entered Value is  333

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
a= input("Enter a Number")
a_float= float(a)

if (a_float < 0):
    print("Number is Negative")
elif(a_float > 0):
    print("Number is Positive")
else:
    print("Number is Zero")
# Out:
# Number is Negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
number1= float(input("Enter First Number"))
number2 = float(input("Enter the Second Number"))
number3= float(input("Enter the Third Number"))

if(number1> number2 and number1> number3 ):
    print({number1}," is Largest")
elif(number2> number1 and number2> number3 ):
    print({number2}," is Largest")
else:
        print(f"{number3} is Largest")
# Out:
# {83.0}  is Largest

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
def factorial(n):
    if (n == 0):
        return 1
    else:
        return n * factorial (n -1)
    
num = int(input("Enter the number "))

print(f" Factorial of {num} is {factorial(num)}")
# Out:
#  Factorial of 1 is 1

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here

integer_var = 10
float_var = 5.5
string_var = "Kulvinder"
boolean_var = True 

print(f" Integer value is {integer_var}  Type: {type(integer_var)}")
print(f" Float value is {float_var}  Type: {type(float_var)}")
print(f" String is {string_var}  Type: {type(string_var)}")
print(f" Boo value is {boolean_var}  Type: {type(boolean_var)}")
# Out:
#  Integer value is 10  Type: <class 'int'>
#  Float value is 5.5  Type: <class 'float'>
#  String is Kulvinder  Type: <class 'str'>
#  Boo value is True  Type: <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a=10
b= 20
print("Before Swap")
print(f"a= {a} ---- b = {b}")

a,b = b,a
print("After  Swap")
print(f"a= {a} ---- b = {b}")
# Out:
# Before Swap
# a= 10 ---- b = 20
# After  Swap
# a= 20 ---- b = 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celsius = float(input("Enter the Temperature in Celsius"))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius} °C is equal to {fahrenheit}°F")
# Out:
# 30.0 °C is equal to 86.0°F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here

str1 = "kulvinder"
str2 = "singh"
concatenated_string = str1 +" "+ str2
print(concatenated_string)
# Out:
# kulvinder singh

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var = 11

if isinstance(var, float):
    print(f"{var} is a Float")
else:
    print(f"{var} is Not a Float")
# Out:
# 11 is Not a Float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = 10
b = 13

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
# Out:
# Addition: 10 + 13 = 23
# Subtraction: 10 - 13 = -3
# Multiplication: 10 * 13 = 130
# Division: 10 / 13 = 0.7692307692307693

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 15
b = 18

print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
# Out:
# 15 == 18: False
# 15 != 18: True
# 15 > 18: False
# 15 < 18: True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False

print(f"True and False: {a and b}")
print(f"True or False: {a or b}")
print(f"not True: {not a}")
# Out:
# True and False: False
# True or False: True
# not True: False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
number = float(input("Enter a Number"))
square = number ** 2
print(f"Square of {number} is {square}")
# Out:
# Square of 10.0 is 100.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
number_EO = float(input("Enter a Number"))
if(number_EO % 2 ==0 ):
    print(f"Number is Even")
else:
     print(f"Number is Odd")
# Out:
# Number is Odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n= float (input("Enter the Number"))
n_sum = (n * (n-1))//2
print(f"Sum of first {n} natural numbers is {n_sum}")
# Out:
# Sum of first 3.0 natural numbers is 3.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here

year = int(input("Enter the Year "))
if (year % 4 ==0) and (year % 100 != 0 ) or (year % 400 ==0):
    print(f" {year} is a Leap Year")
else :
    print(f" {year} is Not a Leap Year")
# Out:
#  2028 is a Leap Year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
string = input("Enter the String")
reverse_string = string[::-1]
print(reverse_string)
# Out:
# hgnis

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
# Your code here
string = input("Enter the String")
reverse_string = string[::-1]
if (string == reverse_string):
    print("String is Palindrome")
else:
    print("String is not Palindrome")
# Out:
# String is Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sort list:{numbers}")
# Out:
# Sort list:[2, 2, 2, 4, 6, 24, 65, 86, 688]
