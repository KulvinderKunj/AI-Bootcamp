# %%
# if statemt 
age = 20
if age>=18:
    print("You are allowed to vote in elections")
# Out:
# You are allowed to vote in elections

# %%
# else 
# if statemt 
age = 17
if age>=18:
    print("You are allowed to vote in elections")
else:
    print("You are NOT allowed to vote in elections")
# Out:
# You are NOT allowed to vote in elections

# %%
# elif  
age = 13
if age <=13:
    print("Your are Child")
elif age <18:
    print("You are a Teenager")
else:
    print ("You are an Adult")
# Out:
# Your are Child

# %%
# nested if else 

# Number is Even, odd or Negative 
num = int (input("Enter the Number"))


if (num >0):
    if(num % 2 ==0):
        print("The Number is Even")
    else:
        print("Number is odd")

else:
    print("The Number is Negative")
# Out:
# Number is odd

# %%
#practical Examples
# Determinte if a Year is a Leap Year or Not using nested conditions 
year = int(input("Enter the Year"))


if(year % 4 ==0):
    if(year % 100 == 0):
        if(year % 400 == 0):
            print("Year is a Leap year")
        else:
            print("Year is not a leap year")
    else:
         print("Year is a leap year")
    
else:
     print("Year is not a leap year")
# Out:
# Year is not a leap year

# %%
#Calcualator 


num1= float(input("Enter the First Number"))
operator = input("Enter the Operator +,-,*,/")

num2= float(input("Enter the Second Number"))



if(operator == '+'):
    result =num1 + num2
elif(operator == '-'):
    result =num1 - num2
elif(operator == '*'):
    result =num1 * num2
elif(operator == '/'):
    if(num2 == 0):
        result = 'undefined'
    else:
        result =num1 / num2

else:
    result ="Invalid"

print(f"The result is  {result}" )
# Out:
# The result is  Invalid

# %%
#Ticket Calculator based on age
age = int(input("Enter the age"))
is_student = input("Are you a student (yes/no)").lower()


if age < 5 :
    price = "Free"
elif age<= 12:
    price = '$10'
elif age <=17:
    if is_student == 'yes':
        price = '$12'
    else:
        price = '$15'
elif age <=64:
    if is_student == 'yes':
        price = '$18'
    else:
        price = "$25"
else:
    price = "$20"



print("Ticket Price: ", price)
# Out:
# Ticket Price:  $20
