# %% [markdown]
# ## Encapsulation
# Encapsulation is the. concept of wrapping data (Variables) and methODS (functions) togeather as a single unit to  restrict direct access to some of the object's components, which means of preventing accidental interference and misuse of the data.

# %%
# Encapsulation getter and setter 
# public, protected, and private variable 
class Person:
    def __init__(self, name, age):
        self.name =name #public variable 
        self.age= age #publice variable 

# Public Variable: can use outside the class 



person =Person("Kulvinder", 26)



print(person.age)



def get_name(person):
    return person.name
print(get_name(person))


dir(person)
# Out:
# 26
# Kulvinder
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Person2:
    def __init__(self, name, age):
        self.__name =name #private variable 
        self.__age= age #private variable 

# Private Variable: can't use outside the class not even child class 



person =Person2("Kulvinder", 26)




dir(person)
# Out:
# ['_Person2__age',
#  '_Person2__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Person3:
    def __init__(self, name, age):
        self._name =name #protected variable 
        self._age= age #protected variable 

# Protected Variable: can't use outside the class but can in child class 

# Child Class 
class Employee(Person3):
    def __init__(self, name, age):
        super().__init__(name, age)


employee= Employee("Kulvinder",26)

print(employee._name)
# print(person.__age)
# Out:
# Kulvinder

# %%
# Encapsulation
class Person4 :
    def __init__(self, name,age):
        self.__name = name
        self.__age=age

    # getter Method
    def get_name(self):
        return self.__name
    def get_age(self):
        return self.__age
        # setter Method
    def set_name(self, name):
         self.__name=name
    def set_age(self,age):
             if age >0:
                self.__age=age


person = Person4("singh", 26)
print(person.get_name())
print(person.get_age())
person.set_age(24)
person.set_name("Kulvinder")

print(person.get_name())
print(person.get_age())
# Out:
# singh
# 26
# Kulvinder
# 24
