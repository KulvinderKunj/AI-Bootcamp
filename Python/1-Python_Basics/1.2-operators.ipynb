# %% [markdown]
# ## Arithimetic Operation

# %%
a = float(input("Enter the First Number:"))
b = float(input("Enter the Second Number:"))

resutl_add = a+b # addition     
resutl_sub = a-b # subtraction 
resutl_mult = a*b #multipication    
resutl_div = a/b # division     
resutl_floor = a//b # Floor Division //remove the decimal value give the floor value 
resutl_mod = a%b
resutl_expo = a**b


print(resutl_add)
print(resutl_sub)
print(resutl_mult)
print(resutl_div)
print(resutl_floor)
print(resutl_mod)
print(resutl_expo)
# Out:
# 89.0
# -21.0
# 1870.0
# 0.6181818181818182
# 0.0
# 34.0
# 1.7034933295672684e+84

# %% [markdown]
# ## Comparison Operator

# %%
#Comparison Operator 
# == equal to 

a=10 
b = 10 
a==b
# Out:
# True

# %%
str1 = "Kulvinder"
str2 = "Kulvinder"
str1 == str2
# Out:
# True

# %%
# != Not Equal to 
str1 != str2
# Out:
# False

# %%
str3 = "Kulvinder"
str4 = "kulvinder"
str3 != str4
# Out:
# True

# %%
# Greater than 
num1 = 45
num2 = 55

num1 > num2
# Out:
# False

# %%
# Less than 
num1< num2
# Out:
# True

# %%
# greater than 0r equal to  >=
number1 = 45
number2 = 45
number1 >= number2
# Out:
# True

# %%
# less than 0r equal to  <=

number1 <= number2
# Out:
# True

# %% [markdown]
# ## Logical Operator

# %%
# And 
X= True
Y= True
reslt = X and Y
print(reslt)
# Out:
# True

# %%
# And 
X= False
Y= True
reslt = X and Y
print(reslt)
# Out:
# False

# %%
# OR
X= True
Y= True
reslt = X or Y
print(reslt)
# Out:
# True

# %%
# OR
X= False
Y= True
reslt = X or Y
print(reslt)
# Out:
# True

# %%
# OR
X= False
Y= False
reslt = X or Y
print(reslt)
# Out:
# False

# %%
# Not  (inverse )
X = True
not X
# Out:
# False
