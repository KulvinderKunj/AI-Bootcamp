# %%
import os
# Create a new diretory 
new_dir = "pakage"
os.mkdir(new_dir)
print(f"Directory {new_dir} created!")
# Out:
# Directory pakage created!

# %%
# LIsting all the files 
items =os.listdir('.')

print(items)
# Out:
# ['destination.txt', 'pakage', 'example.txt', '6.2-filePath.ipynb', '6.1_fileOperations.ipynb']

# %%
# Joining Path 

dir_name = "folder"
file_name= "file.txt"
full_path = os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
# Joining Path 

dir_name = "folder"
file_name= "file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# /Users/kulvindersingh/Desktop/AI-Bootcamp/Python/6-File_handling/folder/file.txt

# %%
path = "example.txt"

if os.path.exists(path):
    print(f"The path {path} Exist")
else:
    print(f"The path {path} does not exist")
# Out:
# The path example.txt Exist

# %%
# Checking the path is file or directory 
path = "pakage"
if os.path.isfile(path):
    print(f"The path {path} is a file")
elif os.path.isdir(path):
    print(f"The path {path} is a Directory")

else:
    print(f"The Path {path} is neither file nor Directory")
# Out:
# The path pakage is a Directory

# %%
# getting the absolute path 
relative_path = "example.txt"
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /Users/kulvindersingh/Desktop/AI-Bootcamp/Python/6-File_handling/example.txt
