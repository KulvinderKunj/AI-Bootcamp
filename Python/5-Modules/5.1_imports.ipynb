# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(25))
print(sqrt(16))
print(pi)
# Out:
# 5.0
# 4.0
# 3.141592653589793

# %%
import numpy as np


import sys
print(sys.executable)
# Out:
# c:\Users\kalvi\Desktop\AI_Bootcamp\venv\python.exe

# %%
#callinf custom packages

from packeges import maths
maths.addition(2,4)
# Out:
# 6

# %%
print(maths.subb(11,2))
# Out:
# 9

# %%
from packeges.subpackage import multi

print(multi.multiply(2,8))
# Out:
# 16
