# %% [markdown]
# Variables

# %%
a= 100

# %%
##Declaring and Assigning Variables
age = 25
height =5.10
name = "Kulvinder Singh"
is_student = True

##printing the variables 

print ("age : ", age)
print("Height : ", height)
print("Name : ", name)
# Out:
# age :  25
# Height :  5.1
# Name :  Kulvinder Singh

# %%
## Naming Conventions 
##Variable names should be descriptive
##They must start with a letter or an '_' and contains, numbers and underscore
##variable names case sensitive


#valid variable 
first_name = "Kulvinder"
last_name="Singh"

##invalid variables 
# first-name =  "kulvinder"
# @name = "k"
# 2name ="kulvinder"

# %%
## Case sensitivity 
name ='Kulvinder'
Name = "Singh"
name  == Name
# Out:
# False

# %%
# Understanding Variable Types
# Python is dynamically typed, the type of variable is determined at run time
age =25 #int
height = 5.10 #float
name = "Kulvinder" #str
print (type(name))
print (type(age))
print (type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
# Type checking and conversion 

type(height)
# Out:
# float

# %%
age =25

print(age)

# Type conversion 
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# 25
# 25
# <class 'str'>

# %%
age ="25"
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name = "Kulvinder"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 name = "Kulvinder"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Kulvinder'

# %%
height = 5.10
type(height)
float_height = float(height)
type(float_height)
# Out:
# float

# %%
int(height)
float(int(height))
# Out:
# 5.0

# %%
# Dynamic Typing 
var = 10 
print(var, type(var))
# python allow the type of variable to change while the program execute 

var ="Hello World !"
print (type(var))
var = 3.4
print(type(var))
# Out:
# 10 <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# Input 
age = int(input("What is your age  ?"))
print(age, type(age))
# Out:
# 25 <class 'int'>

# %%
type(age)
# Out:
# str

# %%
# calcuator

num1 = float (input("Enter the first Number" ))
num2 = float (input("Enter the second Number" ))

sum = num1 +num2
product = num1 * num2 
difference = num1 - num2
quotIent = num1 / num2


print("Sum :", sum)
print("Difference: ", difference)
print("Product:", product)
print("Quotient:", quotIent)
# Out:
# Sum : 80.0
# Difference:  -76.0
# Product: 156.0
# Quotient: 0.02564102564102564
